# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.2)

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet

# %%
word = "happy"

synonyms = set()

for syn in wordnet.synsets(word):
    for lemma in syn.lemmas():
        synonyms.add(lemma.name())

print("Synonyms:", synonyms)
# Out:
# Synonyms: {'happy', 'well-chosen', 'glad', 'felicitous'}

# %%
word = "happy"

antonyms = set()

for syn in wordnet.synsets(word):
    for lemma in syn.lemmas():
        if lemma.antonyms():
            antonyms.add(lemma.antonyms()[0].name())

print("Antonyms:", antonyms)
# Out:
# Antonyms: {'unhappy'}

# %%
word = "dog"

hypernyms = set()

for syn in wordnet.synsets(word):
    for hyper in syn.hypernyms():
        hypernyms.add(hyper.name())

print("Hypernyms:", hypernyms)
# Out:
# Hypernyms: {'support.n.10', 'villain.n.01', 'domestic_animal.n.01', 'catch.n.06', 'sausage.n.01', 'canine.n.02', 'chap.n.01', 'unpleasant_woman.n.01', 'pursue.v.02'}

# %%
for syn in wordnet.synsets("dog"):
    for hyper in syn.hypernyms():
        print(hyper.lemmas()[0].name())
# Out:
# domestic_animal
# canine
# unpleasant_woman
# chap
# villain
# sausage
# catch
# support
# pursue

# %%
text = "The dog chased a cat in the park."
words = text.lower().split()

# %%
for word in words:
    synsets = wordnet.synsets(word)
    if synsets:
        print("\nWord:", word)
        print("Synonyms:", [lemma.name() for lemma in synsets[0].lemmas()])
# Out:
# Word: dog
# Synonyms: ['dog', 'domestic_dog', 'Canis_familiaris']
#
# Word: chased
# Synonyms: ['pursued', 'chased']
#
# Word: a
# Synonyms: ['angstrom', 'angstrom_unit', 'A']
#
# Word: cat
# Synonyms: ['cat', 'true_cat']
#
# Word: in
# Synonyms: ['inch', 'in']
